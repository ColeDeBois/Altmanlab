# %%
from experiment import *
# %reload_ext autoreload
# %autoreload 2

params = (968872.5091425295,652219.0269692114,1.81351143628122e-05,1.722294477970062e-05,-6.651860692596738e-08,-5.693150723984048e-07)
data = Active_Analysis('250226/bead3', params)
# Out:
# Calibration parameters:
# Sx:  968872.5091425295
# Sy:  652219.0269692114
# kx:  1.81351143628122e-05
# ky:  1.722294477970062e-05
# trapx:  -6.651860692596738e-08
# trapy:  -5.693150723984048e-07

# %%
data.calibrate_function_gen()

# %%
data.final_analysis()
# Out:
# /Users/coledebois/Altman lab/Altmanlab/experiment.py:392: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.plot(t, sinefit(t, *params), 'r-')
# /Users/coledebois/Altman lab/Altmanlab/experiment.py:423: OptimizeWarning: Covariance of the parameters could not be estimated
